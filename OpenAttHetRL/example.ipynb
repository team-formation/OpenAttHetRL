# %%
from  scr.data_preprocessing import  data_preprocessing
data_preprocessing.createdata("notebook/AtHetLearning/data/","android")
# Out:
# start
# done!!!
# Answer 231 belongs to unknown Question 144 at Process QA
# Answer 269 belongs to unknown Question 476 at Process QA
# Answer 279 belongs to unknown Question 476 at Process QA
# Answer 304 belongs to unknown Question 476 at Process QA
# Answer 314 belongs to unknown Question 476 at Process QA
# Answer 317 belongs to unknown Question 312 at Process QA
# Answer 407 belongs to unknown Question 476 at Process QA
# Answer 465 belongs to unknown Question 463 at Process QA
# Answer 469 belongs to unknown Question 467 at Process QA
# Answer 477 belongs to unknown Question 476 at Process QA
# Answer 478 belongs to unknown Question 476 at Process QA
# Answer 479 belongs to unknown Question 476 at Process QA
# Answer 480 belongs to unknown Question 476 at Process QA
# Answer 481 belongs to unknown Question 476 at Process QA
# Answer 482 belongs to unknown Question 476 at Process QA
# Answer 484 belongs to unknown Question 483 at Process QA
# ...

# %%
import numpy as np
import tensorflow as tf
from networkx import to_numpy_matrix
import networkx as nx
import datetime
import sys
import os
import pickle
try:
    import ujson as json
except:
    import json
import math
from scipy.linalg import fractional_matrix_power
import random
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import math

print(np.__version__)
print(tf.__version__)
print(nx.__version__)
#print(pickle.__version__)
print(json.__version__)
print(matplotlib.__version__)
# Out:
# 1.18.5
# 2.1.0
# 2.4
# 2.0.9
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d1cb0ce1f8ee> in <module>
#      23 #print(pickle.__version__)
#      24 print(json.__version__)
# ---> 25 print(matplotlib.__version__)
#
# NameError: name 'matplotlib' is not defined

# %%
import os
try:
    import ujson as json
except:
    import json
import sys
from lxml import etree
from bs4 import BeautifulSoup
import string, random
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.data.path.append("../data/nltk_data")
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

import logging
from collections import Counter
import numpy as np
import re
from shutil import copyfile



print(nltk.__version__)
#print(pickle.__version__)
print(re.__version__)
print(shutil.__version__)
# Out:
# 3.5
# 2.2.1
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rooha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rooha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-372ed6c91e02> in <module>
#      26 #print(pickle.__version__)
#      27 print(re.__version__)
# ---> 28 print(shutil.__version__)
#
# NameError: name 'shutil' is not defined

# %%
from  AttHetRL.preprocessing import  datapreprocessing
datapreprocessing.createdata("notebook/AtHetLearning/data/","android")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4ad86355f47a> in <module>
#       1 from  AttHetRL.preprocessing import  datapreprocessing
# ----> 2 datapreprocessing.createdata("notebook/AtHetLearning/data/","android")
#
# ~\anaconda3\lib\site-packages\AttHetRL\preprocessing.py in createdata(path, data)
#    1115
#    1116     def createdata(path,data):
# -> 1117         ob=datapreprocessing(data,path)
#    1118         ob.run()
#    1119
#
# NameError: name 'data_preprocessing' is not defined

# %%
from  AttHetRL.preprocessing import  datapreprocessing # import the class
datapreprocessing.createdata("notebook/AtHetLearning/data/","android") # pass the location and dataset
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rooha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rooha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# start
# done!!!
# Answer 231 belongs to unknown Question 144 at Process QA
# Answer 269 belongs to unknown Question 476 at Process QA
# Answer 279 belongs to unknown Question 476 at Process QA
# Answer 304 belongs to unknown Question 476 at Process QA
# Answer 314 belongs to unknown Question 476 at Process QA
# Answer 317 belongs to unknown Question 312 at Process QA
# Answer 407 belongs to unknown Question 476 at Process QA
# Answer 465 belongs to unknown Question 463 at Process QA
# Answer 469 belongs to unknown Question 467 at Process QA
# Answer 477 belongs to unknown Question 476 at Process QA
# Answer 478 belongs to unknown Question 476 at Process QA
# ...

# %%
# AttHetRL class to run the framework
from  AttHetRL.framework import  AttHetRL
#perform  function run_train to train the model 
#   parameters: 
#  "data/android": dataset name and location,
#  dim_node=32,dim_word=300  node and word embedding dimentions ,
#  epochs=10,batch_size=16   the number of epochs and batch size
#  returns: trainded model is stored in ./data/android/parsed/model/
AttHetRL.run_train("data/android",dim_node=32,dim_word=300,epochs=10,batch_size=16)

# save node and word embedding vectors
AttHetRL.saveembedings()
# Out:
# A_tilde= (2903, 2903)
# A_hat= (2903, 2903)
# GCNW1= (2903, 32)
# GCNW2= (32, 32)
# train data loaded!!
# Epoch  0: i  49  out of  3862     loss=90.82906
# Epoch  0: i  99  out of  3862     loss=95.32697
# Epoch  0: i  149  out of  3862     loss=86.18693
# Epoch  0: i  199  out of  3862     loss=77.66602
# Epoch  0: i  249  out of  3862     loss=72.76241
# Epoch  0: i  299  out of  3862     loss=67.42057
# Epoch  0: i  349  out of  3862     loss=64.54185
# Epoch  0: i  399  out of  3862     loss=62.67821
# Epoch  0: i  449  out of  3862     loss=60.08429
# Epoch  0: i  499  out of  3862     loss=59.25652
# Epoch  0: i  549  out of  3862     loss=58.00748
# Epoch  0: i  599  out of  3862     loss=57.08385
# Epoch  0: i  649  out of  3862     loss=55.90660
# Epoch  0: i  699  out of  3862     loss=55.25222
# Epoch  0: i  749  out of  3862     loss=55.03340
# Epoch  0: i  799  out of  3862     loss=54.71445
# Epoch  0: i  849  out of  3862     loss=52.71496
# ...

# %%
#load graph 
INPUT=self.dataset+self.parsed+"/CQG.txt"
self.G=nx.Graph();        
self.G=nx.read_weighted_edgelist(INPUT)

#get list of nodes
order = [str(i) for i in range(len(self.G.nodes()))]

#construct the adjacency matrix
A =to_numpy_matrix(self.G, nodelist=order,dtype=np.float32)

#construct the  identity matrix
I = np.eye(self.G.number_of_nodes(),dtype=np.float32)    

# add self-loop to the adjacency matrix
A_tilde = A + I        
print("A_tilde=",A_tilde.shape)

# noemalize A_tilde using the degree matrix to obtain A_hat matrix
Dhat05 = np.array(np.sum(A_tilde, axis=0),dtype=np.float32)[0]
Dhat05 = np.matrix(np.diag(Dhat05),dtype=np.float32)  
Dhat05=fractional_matrix_power(Dhat05,-0.5)  
self.A_hat=np.array(Dhat05*A_tilde*Dhat05,dtype=np.float32)
print("A_hat=",self.A_hat.shape)
